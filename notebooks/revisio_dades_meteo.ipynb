# %%
from config.config import LSTM_DATA_DIR, LSTM_MODELS_DIR, LSTM_CALIBRATED_DIR
import pandas as pd
import os
import glob

# %%
#read files in dir 

files = os.listdir(LSTM_DATA_DIR)
files
# Out:
# ['a01_stats.csv',
#  'a03_stats.csv',
#  'a04_stats.csv',
#  'a05_stats.csv',
#  'a07_stats.csv',
#  'a08_stats.csv',
#  'a11_stats.csv',
#  'a13_stats.csv',
#  'a18_stats.csv',
#  'a19_stats.csv',
#  'a20_stats.csv',
#  'a21_stats.csv',
#  'a22_stats.csv',
#  'a23_stats.csv',
#  'a25_stats.csv',
#  'a28_stats.csv',
#  'a29_stats.csv',
#  'a30_stats.csv',
#  'a34_stats.csv',
#  'a37_stats.csv',
#  'a39_stats.csv',
#  'a42_stats.csv',
#  'a43_stats.csv',
#  'a44_stats.csv',
#  'a45_stats.csv',
#  'a46_stats.csv',
#  'a47_stats.csv',
#  'a48_stats.csv',
#  'a49_stats.csv',
#  'a53_stats.csv',
#  'a54_stats.csv',
#  'a57_stats.csv',
#  'a58_stats.csv',
#  'a59_stats.csv',
#  'a62_stats.csv',
#  'a65_stats.csv',
#  'a66_stats.csv',
#  'a68_stats.csv',
#  'a70_stats.csv',
#  'a73_stats.csv']

# %%
station = 'a45'

# %%
pd.read_csv(LSTM_DATA_DIR / f'{station}_stats.csv').temperature.plot()
# Out:
# <Axes: >

# %%
pd.read_csv(LSTM_DATA_DIR / f'{station}_stats.csv').precipitation.plot()
# Out:
# <Axes: >
